# %%
import pandas as pd
imdb_update = pd.read_csv('https://raw.githubusercontent.com/scalabretta/GroupProject--IMDB/master/Dataset/IMDB-database-update.csv',encoding='latin1')
imdb_update.head()
# Out:
#    movie_ID                               movie_title  duration  color  \
# 0         1                                    Avatar       178      1
# 1         2  Pirates of the Caribbean: At World's End       169      1
# 2         3                     The Dark Knight Rises       164      1
# 3         4                              Spider-Man 3       156      1
# 4         5        Batman v Superman: Dawn of Justice       183      1
#
#    title_year country language content_rating  budget_USD  gross_USD  \
# 0        2009     USA  English          PG-13   237000000  760505847
# 1        2007     USA  English          PG-13   300000000  309404152
# 2        2012     USA  English          PG-13   250000000  448130642
# 3        2007     USA  English          PG-13   258000000  336530303
# 4        2016     USA  English          PG-13   250000000  330249062
#
#        ...       actor_3_facebook?  actor_3_facebook_likes  \
# 0      ...                       1                     855
# ...

# %%
imdb_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3781 entries, 0 to 3780
# Data columns (total 36 columns):
# movie_ID                     3781 non-null int64
# movie_title                  3781 non-null object
# duration                     3781 non-null int64
# color                        3781 non-null int64
# title_year                   3781 non-null int64
# country                      3781 non-null object
# language                     3781 non-null object
# content_rating               3781 non-null object
# budget_USD                   3781 non-null int64
# gross_USD                    3781 non-null int64
# net_USD                      3781 non-null int64
# profitable                   3781 non-null int64
# director_name                3781 non-null object
# director_top20?              3781 non-null object
# director_facebook?           3781 non-null int64
# director_facebook_likes      3781 non-null int64
# actor_1_name                 3781 non-null object
# ...

# %%
# 1. rows=3781 dan column=36
imdb_update.shape
# Out:
# (3781, 36)

# %%
# 2.
# The Hunger Games: Catching Fire
# Despicable Me 2
# Frozen
imdbupdate_2013 = imdb_update[imdb_update.title_year == 2013]
imdbupdate_sortnet = imdbupdate_2013.sort_values(by=['net_USD'], ascending=False)
imdbupdate_sortnet.head(3)
# Out:
#       movie_ID                      movie_title  duration  color  title_year  \
# 1614      1615  The Hunger Games: Catching Fire       146      1        2013
# 236        237                  Despicable Me 2        98      1        2013
# 57          58                           Frozen       102      1        2013
#
#      country language content_rating  budget_USD  gross_USD      ...       \
# 1614     USA  English          PG-13   130000000  424645577      ...
# 236      USA  English             PG    76000000  368049635      ...
# 57       USA  English             PG   150000000  400736600      ...
#
#       actor_3_facebook?  actor_3_facebook_likes cast_total_facebook_likes  \
# 1614                  1                     523                     49355
# 236                   1                    1000                     11905
# 57                    1                     490                      2582
#
#      movie_facebook?  movie_facebook_likes;  facenumber_in_poster  \
# ...

# %%
# 3.
# Avatar
# Transformers: Revenge of the Fallen
# Harry Potter and the Half-Blood Prince
imdbupdate_2009 = imdb_update[imdb_update.title_year == 2009]
imdbupdate_sortgross = imdbupdate_2009.sort_values(by=['gross_USD'], ascending=False)
imdbupdate_sortgross.head(3)
# Out:
#       movie_ID                             movie_title  duration  color  \
# 0            1                                  Avatar       178      1
# 19          20     Transformers: Revenge of the Fallen       150      1
# 3094      3095  Harry Potter and the Half-Blood Prince       153      1
#
#       title_year country language content_rating  budget_USD  gross_USD  \
# 0           2009     USA  English          PG-13   237000000  760505847
# 19          2009     USA  English          PG-13   200000000  402076689
# 3094        2009      UK  English             PG   250000000  301956980
#
#           ...       actor_3_facebook?  actor_3_facebook_likes  \
# 0         ...                       1                     855
# 19        ...                       1                     464
# 3094      ...                       1                   10000
#
#      cast_total_facebook_likes movie_facebook?  movie_facebook_likes;  \
# ...

# %%
# 4.
# non english movie = 153
movie_nonenglish = imdb_update[imdb_update.language != 'English']
len(movie_nonenglish)
# Out:
# 153

# %%
# 5.

# %%
# 6.

# %%
# 7.
# Average Budget All Movies tahun 2013 = USD 51.069.610
imdbupdate_2013 = imdb_update[imdb_update.title_year == 2013]
average_budget_2013 = sum(imdbupdate_2013.budget_USD)/len(imdbupdate_2013.budget_USD)
print(average_budget_2013)
# Out:
# 51069610.77439024

# %%
# 8.
# Average Budget All Movies tahun 2014 = USD 49.919.006
imdbupdate_2014 = imdb_update[imdb_update.title_year == 2014]
average_budget_2014 = sum(imdbupdate_2014.budget_USD)/len(imdbupdate_2014.budget_USD)
print(average_budget_2014)
# Out:
# 49919006.62251656

# %%
# 9.
# Average budget 2013 lebih dari average busget 2014
if (average_budget_2013 > average_budget_2014):
    print('average budget 2013 lebih dari average budget 2014')
elif (average_budget_2013 < average_budget_2014):
    print('average budget 2013 lebih dari average budget 2014')
else:
    print('average budget 2013 sama dengan average budget 2014')
# Out:
# average budget 2013 lebih dari average budget 2014

# %%
# 10
# Avatar : USD 523.505.847
imdbupdate_allyear_sortnet = imdb_update.sort_values(by=['net_USD'], ascending=False)
imdbupdate_allyear_sortnet_id = imdbupdate_allyear_sortnet.set_index('movie_ID')
imdbupdate_allyear_sortnet_id.head(1)
# Out:
#          movie_title  duration  color  title_year country language  \
# movie_ID
# 1             Avatar       178      1        2009     USA  English
#
#          content_rating  budget_USD  gross_USD    net_USD     ...       \
# movie_ID                                                      ...
# 1                 PG-13   237000000  760505847  523505847     ...
#
#           actor_3_facebook? actor_3_facebook_likes cast_total_facebook_likes  \
# movie_ID
# 1                         1                    855                      4834
#
#           movie_facebook?  movie_facebook_likes; facenumber_in_poster  \
# movie_ID
# 1                       1                  33000                    0
#
#           num_voted_users  num_user_for_reviews  imdb_score imdb_top_250
# movie_ID
# 1                  886204                  3054         7.9            0
#
# [1 rows x 35 columns]
